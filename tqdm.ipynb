# %% [markdown]
# ## (1) apply에 적용

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

df_sub = df.loc[:2,:]
df_sub['kkma_description'] = df_sub['description'].progress_apply(preprocessing, args=(kkma,))
