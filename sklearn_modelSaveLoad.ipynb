# %% [markdown]
# [참고블로그](https://gaussian37.github.io/ml-sklearn-saving-model/)

# %% [markdown]
# ## [1] 파일로 저장하기

# %% [markdown]
# + estimator
# + from sklearn.feature_extraction.text import CountVectorizer
# + from sklearn.feature_extraction.text import TfidfTransformer
#
# 들 저장 가능

# %%
import joblib

# cv 결과로 최상 estimator 가져오기
best_sgd_model = sgd_cv.best_estimator_

# 저장
joblib.dump(best_sgd_model, 'best_sgd_model.pkl') 

# 로드
best_sgd_model2 = joblib.load('best_sgd_model.pkl') 


# 예측
pred = best_sgd_model2.predict(x_test)

acc = accuracy_score(pred, y_test)
print(acc)
print('-'*100)
cm = confusion_matrix(y_test, pred)  # y_true, y_pred
print(cm)

print('-'*100)
cr = classification_report(y_test, pred)
print(cr)
