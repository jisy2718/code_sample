# %% [markdown]
# # 1. Read

# %% [markdown]
# ## [1] csv, txt, excel

# %% [markdown]
# ### (1) csv

# %%
import pandas as pd
df = pd.read_csv(filename.csv)

# %% [markdown]
# ### (2) txt with tab space

# %%
import pandas as pd
data = pd.read_csv(filename.txt, sep="\t" )

# %% [markdown]
# ## [2] json

# %% [markdown]
# ### (1) json.load()

# %% [markdown]
# ### (2) json.load() 시, Unexpected UTF-8 BOM python error 뜨는 경우

# %%
# 읽어오기
with open(filename.json, mode="r", encoding="utf-8") as file:
	lines = file.readlines()
	if len(lines) != 0:
		lines[0] = lines[0].replace(u"\ufeff", '')

# 1개의 스트링으로 합친 후,
strings = ''.join(lines)

# json으로 만들기
import json
json_object = json.loads(strings)

# %% [markdown]
# # 2. Write

# %% [markdown]
# ## [1] list, set

# %%
test_lst = ['안녕','하신가','요']
with open("test_lst.txt", "w") as textfile:
    for element in test_lst:
        textfile.write(element + "\n")
