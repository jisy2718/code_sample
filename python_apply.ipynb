# %% [markdown]
# ## [1] 인자 1개

# %%
# apply 이용

# progress_apply 이용


# argument 넣는 거 2가지 방법
args = ()
def sampling_func(data, sample_pct):
    np.random.seed(1)
    N = min(200,len(data))
    sample_n = int(N*sample_pct) # integer
    sample = data.take(np.random.permutation(N)[:sample_n])
    return sample

## 1. 
sample_df = df.groupby('new_topic', group_keys=False).progress_apply(sampling_func, sample_pct=1)

## 2. args
sample_df = df.groupby('new_topic', group_keys=False).progress_apply(sampling_func, args=(1,))

# %% [markdown]
# ## [2] 인자 2개
# + [블로그참고](https://chancoding.tistory.com/191)

# %%
import pandas as pd
a = pd.DataFrame({'col1':[1,2,3], 'col2':[100,200,300]})

def custom_ftn(data):
    one_row_of_col1 = data[0]
    one_row_of_col2 = data[1]
    return one_row_of_col1 + one_row_of_col2

a['sum'] = a.apply(custom_ftn, axis=1)
a
# Out:
#    col1  col2  sum
# 0     1   100  101
# 1     2   200  202
# 2     3   300  303

# %%
# Out:
#    col1  col2  sum
# 0     1   100  101
# 1     2   200  202
# 2     3   300  303
