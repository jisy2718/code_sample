# %% [markdown]
# ## [1] terminal에서 target.py 실행 시, input 받기

# %% [markdown]
# + target.py

# %%
# target.py
def main(argv):
    first_argument = argv[1] 
    second_argument = argv[2] # 1개부터 여러개 넣을 수 있음
    '''
    원하는 작업 수행
    '''

if __name__ == "__main__":
    main(sys.argv)

# %% [markdown]
# + terminal에서 target.py 실행시

# %%
$ python3 target.py argument1 argument2

# %% [markdown]
# ## [2]
